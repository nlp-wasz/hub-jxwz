# %%
from openai import OpenAI
import os
from PIL import Image
import base64
from io import BytesIO

client=OpenAI(api_key='sk-a328a5b2bb7b443d8a51ee9a1991b908',base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")


img = Image.open('./20251106232555.jpg').convert('RGB')
# 转换为 BytesIO 流
buffered = BytesIO()
img.save(buffered, format="JPEG")
img_base64 = base64.b64encode(buffered.getvalue()).decode("utf-8")


response = client.chat.completions.create(
    model="qwen3-vl-plus",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{img_base64}"
                    }
                },
                {
                    "type": "text",
                    "text": "请判断这张图片是还是狗？"
                },
            ],
        },
    ],
)


print(response.choices[0].message.content)
# Out:
# 是狗。
#
# 这张图片中清晰地显示了一只毛茸茸、浅棕色的小狗，它正坐在草地上，张着嘴、吐着舌头，看起来非常开心或在喘气。从它的外形特征（如耳朵、鼻子、四肢、卷毛）和神态来看，这是一只活生生的幼犬，不是其他动物或物体。
#
# ✅ 结论：是狗。
