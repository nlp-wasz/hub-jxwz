# %%
import base64
from zai import ZhipuAiClient

client = ZhipuAiClient(api_key='e67088571ddf4f2789b59730c1586fd8.sM6fYMwvexGk1bAC')

img_path = "./dog.jpeg"
with open(img_path, "rb") as image_file:
    img_base = base64.b64encode(image_file.read()).decode("utf-8")

response = client.chat.completions.create(
    model="glm-4.5v",
    messages=[
        {
            "content": [
                {
                    "type": "image_url",
                    "image_url": {
                        "url": img_base
                    }
                },
                {
                    "type": "text",
                    "text": "这是狗还是猫，为什么？"
                }
            ],
            "role": "user"
        }
    ],
    thinking={
        "type":"disabled"
    },
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.reasoning_content:
        print(chunk.choices[0].delta.reasoning_content, end='', flush=True)

    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end='', flush=True)
# Out:
# 这是狗。判断依据是：从外形特征来看，该动物具有典型的犬类特征，比如较大的体型、竖立的耳朵（部分品种特征）、较长的吻部以及整体身体结构等；而猫的体型通常更小，耳朵形态、面部结构等也有明显区别，图中动物不具备猫的典型特征，因此可以确定是狗。
